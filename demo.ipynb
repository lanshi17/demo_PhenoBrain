# %%
import numpy as np
import pandas as pd
import os
import sys
from pathlib import Path

# %%
PATH_ROOT=Path(os.getcwd())
PATH_ROOT
# Out:
# PosixPath('/mnt/data/Projects/02_Research/demo_PhenoBrain')

# %%
import numpy as np
import pandas as pd
import os
import sys
from pathlib import Path

# %%
PATH_ROOT=Path(os.getcwd())
sys.path.insert(0, str(PATH_ROOT))
from timgroup_disease_diagnosis.codes.core.core.script.example_predict_ensemble import (
    build_ensemble_model,
    predict_ensemble,
    format_results_table,
    describe_available_models,
)

# %%
hpo_list = ["HP:0001913", "HP:0008513", "HP:0001123"]

print(describe_available_models())
results = predict_ensemble(hpo_list, topk=5)
print(format_results_table(results))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 3
#       1 hpo_list = ["HP:0001913", "HP:0008513", "HP:0001123"]
#       2
# ----> 3 results = predict_ensemble(hpo_list, topk=5)
#       4 print(format_results_table(results))
#
# File /mnt/data/Projects/02_Research/05_demo_PhenoBrain/timgroup_disease_diagnosis/codes/core/core/script/example_predict_ensemble.py:349, in predict_ensemble(hpo_list, topk)
#     346 def run_prediction():
#     347     return build_ensemble_model().query(hpo_list, topk)
# --> 349 return run_quietly(run_prediction)
#
# File /mnt/data/Projects/02_Research/05_demo_PhenoBrain/timgroup_disease_diagnosis/codes/core/core/script/example_predict_ensemble.py:105, in run_quietly(fn, *args, **kwargs)
#     103 sink = io.StringIO()
#     104 with redirect_stdout(sink), redirect_stderr(sink):
# --> 105     return fn(*args, **kwargs)
#
# ...
